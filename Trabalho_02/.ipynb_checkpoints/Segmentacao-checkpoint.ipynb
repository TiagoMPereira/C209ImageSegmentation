# %% [markdown]
# ## Segmentação de imagens

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
def histogram(img):
    l, c = img.shape
    histogram = np.zeros(256, dtype=np.int32)

    for i in range(l):
        for j in range(c):
            intensity = img[i, j]
            histogram[intensity] += 1
            
    return histogram
    
def show_histogram(img, img_gray):
    histogram_gray = histogram(img_gray)
    histogram_r = histogram(img[:, :, 0])
    histogram_g = histogram(img[:, :, 1])
    histogram_b = histogram(img[:, :, 2])
    
    plt.figure(figsize=(16, 16))
    plt.subplot(2, 2, 1)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
    plt.subplot(2, 2, 2)
    plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
    plt.subplot(2, 2, 3)
    plt.bar(range(256), histogram_r, color='red')
    plt.bar(range(256), histogram_g, color='green')
    plt.bar(range(256), histogram_b, color='blue')
    plt.subplot(2, 2, 4)
    plt.bar(range(256), histogram_gray)
    
def gray_image(image):
    return((0.2126 * image[:, :, 0]) + (0.7152 * image[:, :, 1]) + (0.0722 * image[:, :, 2])).astype(np.uint8)

# %%
image = np.array(Image.open('estatua.jpg'))
(l, c, p) = image.shape

# Convertendo para grayscale
image_gray = gray_image(image)

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(image_gray, cmap='gray')
plt.show()

# %%
show_histogram(image,image_gray)

# %%
#definindo dois espaços
image_1 = image[200:400, 500:700]
image_2 = image[200:400, 220:420]

image_1_gray = gray_image(image_1)
image_2_gray = gray_image(image_2)

# %%
show_histogram(image_1,image_1_gray)

# %%
show_histogram(image_2,image_2_gray)

# %%
gorila_sem = image[0:150,0:150]
gorila_com = image[100:250, 250:400]

termometro_sem = image[100:300, 300:500]
termometro_com = image[0:100, 200:400]

estatua_sem = image[200:400, 500:700]
estatua_com = image[200:400, 220:420]
