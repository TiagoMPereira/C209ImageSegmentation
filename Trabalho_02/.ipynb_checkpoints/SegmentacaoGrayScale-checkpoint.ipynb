# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
def histogram(img):
    l, c = img.shape
    histogram = np.zeros(256, dtype=np.int32)

    for i in range(l):
        for j in range(c):
            intensity = img[i, j]
            histogram[intensity] += 1
            
    return histogram
    
def show_histogram(img, img_gray):
    histogram_gray = histogram(img_gray)
    histogram_r = histogram(img[:, :, 0])
    histogram_g = histogram(img[:, :, 1])
    histogram_b = histogram(img[:, :, 2])
    
    plt.figure(figsize=(12,12))
    plt.subplot(2, 2, 1)
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)
    plt.subplot(2, 2, 2)
    plt.imshow(img_gray, cmap='gray', vmin=0, vmax=255)
    plt.subplot(2, 2, 3)
    
    plt.bar(range(256), histogram_b, color='blue')
    plt.bar(range(256), histogram_r, color='red')
    plt.bar(range(256), histogram_g, color='green')
    plt.subplot(2, 2, 4)
    plt.bar(range(256), histogram_gray)
    
def gray_image(image):
    return((0.2126 * image[:, :, 0]) + (0.7152 * image[:, :, 1]) + (0.0722 * image[:, :, 2])).astype(np.uint8)

# %%
image = np.array(Image.open('gorila.jpg'))
(l, c, p) = image.shape

# Convertendo para grayscale
image_gray = gray_image(image)

show_histogram(image, image_gray)

# %% [markdown]
# #### Visualizando histograma de parte com o objeto de interesse (temperatura) e sem

# %%
#definindo dois espaços
image_sem =  image[0:150,0:150]
image_com =  image[100:250, 250:400]

image_sem_gray = gray_image(image_sem)
image_com_gray = gray_image(image_com)

# %%
show_histogram(image_sem, image_sem_gray)

# %%
show_histogram(image_com, image_com_gray)

# %% [markdown]
# #### Tons de cinza com alta iluminação na região de interesse
# Limiar será baseado na escala de cinza, sendo assim threshold > 170

# %%
def gray_threshold(image, threshold):
    
    l, c = image.shape
    _bin = np.zeros(shape=(l, c), dtype=np.uint8)
    
    for i in range (l):
        for j in range (c):
            
            value = image[i,j]
            
            if value <= threshold:
                _bin[i,j] = 1
            else:
                _bin[i,j] = 0
                
    return _bin

# %%
def blue_threshold(image, threshold):
    
    l, c, p = image.shape
    red_bin = np.zeros(shape=(l, c), dtype=np.uint8)
    
    for i in range (l):
        for j in range (c):
            
            value_r = image[i,j,0]
            value_g = image[i,j,1]
            value_b = image[i,j,2]
            
            if value_b <= threshold:
                red_bin[i,j] = 1
            else:
                red_bin[i,j] = 0
                
    return red_bin

# %%
threshold = 50
bin_image = gray_threshold(image_gray, threshold)
not_bin = np.invert(bin_image)

# %%
plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.imshow(bin_image, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(not_bin, cmap='gray')
